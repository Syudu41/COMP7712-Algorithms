# %% [markdown]
# # Final Exam

# %% [markdown]
# Topics:
# - Running time equation
# - O, $\Omega$, $\Theta$
# - Master's theorem
# - Explain strategies in English
# - Divide and Conquer
# - Dynamic Programming
# - Backtracking

# %% [markdown]
# ## Date: Thursday May 7, 8AM--10AM

# %% [markdown]
# **How it works**
#
# Either A or B
#
# #### A
# 1. similarly to homework assignment:
#    - You come to class,
#    - Log into the hub
#    - Download the final exam ,
#    - Work on the exam on the Hub
#    - Turn in the exam on the Hub
#    - You can view lecture notes and assignment solutions on your computer
# 2. No communication with anyone/website. If you open any website, you will get an O and a fail on the course
#
# #### B
# 1. You come to class
# 2. You do the exam on paper
# 3. You will need to print out whatever you want
# 4. No communcations with anyone.  Violation: F and fail the course
